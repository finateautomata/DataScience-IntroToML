# %% [markdown]
# # MGTF 495: Project Part 1
# # Housing Sale Price Prediction

# %%
# import libraries
import numpy as np
import pandas as pd

# %%
# Read data
train = pd.read_csv('data/train_new.csv')
test = pd.read_csv('data/test_new.csv')

# %%
train
# Out:
#      Paved Drive BsmtExposure  BsmtUnfinishedArea ProximityToMainRoad2  \
# 0              N          NaN                   0                 Norm
# 1              Y           No                 928                 Norm
# 2              Y           No                2174                 Norm
# 3              Y           Gd                1701                 Norm
# 4              Y           No                 778                 Norm
# ...          ...          ...                 ...                  ...
# 2046           Y           No                1262                 Norm
# 2047           Y           No                 795                 Norm
# 2048           Y           Gd                 527                 Norm
# 2049           Y           No                 413                 Norm
# 2050           Y           No                1575                 Norm
#
#      KitchenQuality SaleCondition  LivingArea Lot Config FenceQuality  \
# 0                TA        Normal         845    CulDSac          NaN
# 1                TA        Normal        1329     Inside          NaN
# 2                TA        Normal        1967     Inside          NaN
# 3                Gd        Normal        1614     Inside          NaN
# 4                TA        Normal        1904     Inside        GdPrv
# ...             ...           ...         ...        ...          ...
# 2046             Gd        Normal        1845     Inside        GdPrv
# 2047             TA        Normal        2555     Inside          NaN
# 2048             TA        Normal        1081     Inside          NaN
# 2049             TA        Normal        1167     Inside          NaN
# 2050             Gd       Partial        1368     Inside          NaN
#
#      SaleType  ...  BsmtFinish1Area Quality GarageType  LotSize Kitchens  \
# 0          WD  ...                0       4     Detchd    11500        1
# 1          WD  ...              608       7     Attchd    12285        1
# 2          WD  ...                0       5     Attchd     9662        2
# 3          WD  ...              120       7     Attchd     9316        1
# 4          WD  ...              244       5     Attchd     7200        1
# ...       ...  ...              ...     ...        ...      ...      ...
# 2046       WD  ...                0       6     Attchd    11218        1
# 2047       WD  ...                0       6     Detchd    11526        1
# 2048       WD  ...              761       6    CarPort    12929        1
# 2049       WD  ...              709       5     Detchd     8731        1
# 2050      New  ...                0       7     Attchd     6955        1
#
#      GarageYearBuilt BuildingClass 2ndFloorArea  1stFloorArea  SalePrice
# 0             1957.0            20            0          1889   110720.0
# 1             1960.0            20          252          2373   212091.0
# 2             1977.0            90          252          3011   190563.0
# 3             2005.0            20          252          2658   265887.0
# 4             1950.0            50         1020          2180   170146.0
# ...              ...           ...          ...           ...        ...
# 2046          1992.0            60         1042          2099   226282.0
# 2047          1993.0            70         1000          2467   228462.0
# 2048          1960.0            20          252          2125   181005.0
# 2049          1972.0            30          252          2211   176591.0
# 2050          2005.0           120          252          2412   241012.0
#
# [2051 rows x 80 columns]

# %%
test
# Out:
#      MonthSold TypeOfRoadAccess BsmtHeight Misc Feature  PoolSize SaleType  \
# 0            6             Pave         TA          NaN         0       WD
# 1            2             Pave         Ex          NaN         0       WD
# 2            5             Pave         TA          NaN         0       WD
# 3            1             Pave         TA          NaN         0      Oth
# 4           11             Pave         Gd         Shed         0       WD
# ..         ...              ...        ...          ...       ...      ...
# 874          3             Pave         Ex          NaN         0       WD
# 875          8             Pave         TA          NaN         0       WD
# 876          6             Pave         Gd          NaN         0       WD
# 877          8             Pave         TA          NaN         0       WD
# 878         12             Pave         TA          NaN         0       WD
#
#     HeatingQuality TypeOfAlleyAccess KitchenQuality ProximityToMainRoad2  ...  \
# 0               Fa              Grvl             Gd                 Norm  ...
# 1               Ex               NaN             Ex                 Norm  ...
# 2               Ex               NaN             TA                 Norm  ...
# 3               TA               NaN             TA                 Norm  ...
# 4               Ex               NaN             TA                 Norm  ...
# ..             ...               ...            ...                  ...  ...
# 874             Ex               NaN             Gd                 Norm  ...
# 875             TA               NaN             TA                 Norm  ...
# 876             Gd              Pave             TA                 Norm  ...
# 877             TA               NaN             TA                 Norm  ...
# 878             TA               NaN             TA                 Norm  ...
#
#     TotalRooms  BsmtFinishType1  MasVnrArea Misc LotFrontage GarageCondition  \
# 0            7              Unf         0.0    0         NaN              TA
# 1            6              GLQ       122.0    0        77.0              TA
# 2            5              Unf       279.0    0        60.0              TA
# 3           10              BLQ       144.0    0        98.0             NaN
# 4            7              ALQ       240.0  350         NaN              TA
# ..         ...              ...         ...  ...         ...             ...
# 874          7              GLQ        42.0    0       107.0              TA
# 875          6              Rec       104.0    0        80.0              TA
# 876          5              GLQ      1129.0    0        34.0              TA
# 877          7              Unf         0.0    0       115.0              TA
# 878          6              Rec       356.0    0        21.0              TA
#
#     BsmtUnfinishedArea  Shape ExteriorQual  FullBaths
# 0                795.0    Reg           TA          1
# 1                610.0    IR1           Gd          2
# 2               1015.0    Reg           TA          1
# 3                371.0    IR1           TA          2
# 4                318.0    IR1           TA          2
# ..                 ...    ...          ...        ...
# 874              940.0    IR1           Gd          2
# 875              543.0    Reg           TA          2
# 876              453.0    Reg           TA          2
# 877              927.0    Reg           TA          2
# 878              423.0    Reg           TA          2
#
# [879 rows x 79 columns]

# %%
#check the numbers of samples and features
print("The train data size before dropping Id feature is : {} ".format(train.shape))
print("The test data size before dropping Id feature is : {} ".format(test.shape))

#Save the 'Id' column
train_ID = train['ID']
test_ID = test['ID']

#Now drop the  'Id' colum since it's unnecessary for  the prediction process.
train.drop("ID", axis = 1, inplace = True)
test.drop("ID", axis = 1, inplace = True)

#check again the data size after dropping the 'Id' variable
print("\nThe train data size after dropping Id feature is : {} ".format(train.shape)) 
print("The test data size after dropping Id feature is : {} ".format(test.shape))
# Out:
# The train data size before dropping Id feature is : (2051, 81)
# The test data size before dropping Id feature is : (879, 80)
#
# The train data size after dropping Id feature is : (2051, 80)
# The test data size after dropping Id feature is : (879, 79)

# %%
def rmse(y_true, y_pred):
    """Root Mean Squared Error"""
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %% [markdown]
# ## `SalePrice` Baseline
# ### Predict the global average sale price.

# %%
y_pred = train.SalePrice.values.mean() * np.ones(test.shape[0])

# %% [markdown]
# # Submission

# %%
# create submission file
sub = pd.DataFrame()
sub['Id'] = test_ID
sub['SalePrice'] = y_pred
sub.to_csv('baseline_submission_new.csv', index=False)
